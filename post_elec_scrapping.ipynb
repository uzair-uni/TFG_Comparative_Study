# %%
import os
import re
import time
import random
import requests
from bs4 import BeautifulSoup
from google.colab import drive

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def extract_trump_statements(text):
    """Extracts only statements made by Trump from a speech transcript."""
    out_lines = []
    capturing = True  # Flag to track when Trump starts speaking

    lines = text.split("\n")

    for line in lines:
        line = line.strip()

        if re.match(r'^(PRESIDENT TRUMP:|THE PRESIDENT:|Donald Trump:|TRUMP:|President Trump:|Mr. Trump:|President Donald J. Trump:)', line, re.IGNORECASE):
            capturing = True  # Start capturing Trump's speech
            line = re.sub(r'^(PRESIDENT TRUMP:|THE PRESIDENT:|Donald Trump:|TRUMP:|President Trump:|Mr. Trump:|President Donald J. Trump:)', "", line, flags=re.IGNORECASE).strip()
            out_lines.append(line)

        # Stop capturing if another speaker is detected
        elif re.match(r'^[A-Za-z\s.]+:', line):
            capturing = False

        elif capturing:
            out_lines.append(line)

    return "\n".join(out_lines).strip()


def remove_questions(transcript):

    cleaned_transcript = re.sub(r'(?m)^Q\s+.*?\n', '', transcript)

    return cleaned_transcript.strip()

# %%
# Set folder path in Google Drive
SAVE_FOLDER = "/content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS"
os.makedirs(SAVE_FOLDER, exist_ok=True)

# Base URL
BASE_URL = "https://trumpwhitehouse.archives.gov"
start_url = "https://trumpwhitehouse.archives.gov/remarks/page/199/"

def scrape_page(url):
    global count
    global stop_scraping
    print(f"Fetching page: {url}")

    response = requests.get(url)
    if response.status_code != 200:
        print(f"Error fetching page: {url}")
        return None

    soup = BeautifulSoup(response.text, "html.parser")
    # page = soup.find("page-results")

    if not soup:
        print("No content found on the page.")
        return None

    for article in soup.find_all("article"):
        if stop_scraping:
            break

        title_link = article.find("a")

        if not title_link:
            continue

        title = title_link.text.strip()
        link = title_link["href"]
        date = article.find("time").text.strip()

        year = int(date[-4:])
        if year != 2017 or count >= 200:
            print('Scraping stopped with',count, 'documents scraped until year', year)
            stop_scraping = True
            break

        print(f"Fetching document: {title} ({date})")
        if "trump" not in title.lower() and 'address' not in title.lower():
            print(f"Title does not contain 'trump': {title}")
            continue

        time.sleep(random.uniform(2, 5))

        doc_response = requests.get(link)
        if doc_response.status_code != 200:
            print(f"Failed to fetch document: {link}")
            continue

        doc_soup = BeautifulSoup(doc_response.text, "html.parser")
        content_div = doc_soup.find("div", {"class": "page-content__content editor"})

        if content_div:
            paragraphs = content_div.find_all("p")
            text = "\n".join(p.get_text(strip=True) for p in paragraphs)  # Join text content
        else:
            print("Content not found.")

        # retaining trump-only text
        extracted_text = extract_trump_statements(text)

        # removing the questions
        script = remove_questions(extracted_text)

        word_count = len(script.split())
        if word_count < 450:
            print(f"Skipping {title} ({date}) - Only {word_count} words.")
            continue

        clean_title = re.sub(r"[^\w\-_]", "_", title)
        filename = f"{SAVE_FOLDER}/{clean_title}.txt"

        with open(filename, "w", encoding="utf-8") as file:
            file.write(f"{script}")

        print(f"Saved to Google Drive: {filename} ({word_count} words)\n")
        count += 1

    return soup

def get_previous_page(soup):
    prev_link = soup.find("a", class_="pagination__prev")  # Search by class
    if prev_link and "href" in prev_link.attrs:
        return prev_link["href"]
    return None

current_url = start_url
stop_scraping = False
count = 0

while current_url and not stop_scraping:
    soup = scrape_page(current_url)
    if soup:
        current_url = get_previous_page(soup)
    else:
        break
# Out:
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/199/
# Fetching document: Remarks by President Trump and Vice President Pence at CIA Headquarters (Jan 21, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Vice_President_Pence_at_CIA_Headquarters.txt (2395 words)
#
# Fetching document: The Inaugural Address (Jan 20, 2017)
# Skipping The Inaugural Address (Jan 20, 2017) - Only 405 words.
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/198/
# Fetching document: Remarks by President Trump in Strategy and Policy Forum (Feb 3, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Strategy_and_Policy_Forum.txt (1049 words)
#
# Fetching document: Remarks by President Trump at Signing of Executive Order on Fiduciary Rule (Feb 3, 2017)
# Skipping Remarks by President Trump at Signing of Executive Order on Fiduciary Rule (Feb 3, 2017) - Only 66 words.
# Fetching document: Remarks by President Trump at National Prayer Breakfast (Feb 2, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_National_Prayer_Breakfast.txt (2392 words)
#
# Fetching document: Remarks by President Trump Before Meeting with Harley-Davidson Executives and Union Representatives (Feb 2, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_Before_Meeting_with_Harley-Davidson_Executives_and_Union_Representatives.txt (888 words)
#
# Fetching document: Remarks by President Trump in Meeting with SCOTUS Groups (Feb 1, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Meeting_with_SCOTUS_Groups.txt (757 words)
#
# Fetching document: Remarks by President Trump in African American History Month Listening Session (Feb 1, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_African_American_History_Month_Listening_Session.txt (1272 words)
#
# Fetching document: Remarks by President Trump and Vice President Pence at Swearing-In Ceremony for Secretary of State Rex Tillerson (Feb 1, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Vice_President_Pence_at_Swearing-In_Ceremony_for_Secretary_of_State_Rex_Tillerson.txt (451 words)
#
# Fetching document: Remarks of Vice President Pence – As Delivered at the Swearing-in Ceremony for Transportation Secretary Elaine Chao (Jan 31, 2017)
# Title does not contain 'trump': Remarks of Vice President Pence – As Delivered at the Swearing-in Ceremony for Transportation Secretary Elaine Chao
# Fetching document: Remarks by Vice President Mike Pence, Second Lady Karen Pence, and Counselor to the President Kellyanne Conway to the March for Life (Jan 27, 2017)
# Title does not contain 'trump': Remarks by Vice President Mike Pence, Second Lady Karen Pence, and Counselor to the President Kellyanne Conway to the March for Life
# Fetching document: President Trump and Prime Minister May’s Opening Remarks (Jan 27, 2017)
# Skipping President Trump and Prime Minister May’s Opening Remarks (Jan 27, 2017) - Only 233 words.
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/197/
# Fetching document: Remarks by the Vice President at West Point (Feb 9, 2017)
# Title does not contain 'trump': Remarks by the Vice President at West Point
# Fetching document: Remarks by President Trump at Swearing-In of Attorney General Sessions (Feb 9, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Swearing-In_of_Attorney_General_Sessions.txt (496 words)
#
# Fetching document: Remarks by President Trump Before SCOTUS Listening Session (Feb 9, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_Before_SCOTUS_Listening_Session.txt (698 words)
#
# Fetching document: Remarks by President Trump in Meeting with the Aviation Industry (Feb 9, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Meeting_with_the_Aviation_Industry.txt (2042 words)
#
# Fetching document: Background Press Call on Prime Minister Abe’s Visit to the White House (Feb 9, 2017)
# Title does not contain 'trump': Background Press Call on Prime Minister Abe’s Visit to the White House
# Fetching document: Remarks by President Trump at MCCA Winter Conference (Feb 8, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_MCCA_Winter_Conference.txt (3482 words)
#
# Fetching document: Remarks by President Trump and Intel CEO Brian Krzanich on U.S. Jobs (Feb 8, 2017)
# Skipping Remarks by President Trump and Intel CEO Brian Krzanich on U.S. Jobs (Feb 8, 2017) - Only 205 words.
# Fetching document: Remarks by President Trump in Roundtable with County Sheriffs (Feb 7, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Roundtable_with_County_Sheriffs.txt (3409 words)
#
# Fetching document: Remarks by President Trump to Coalition Representatives and Senior U.S. Commanders (Feb 6, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_to_Coalition_Representatives_and_Senior_U_S__Commanders.txt (1545 words)
#
# Fetching document: Remarks by Vice President Mike Pence to the Federalist Society (Feb 4, 2017)
# Title does not contain 'trump': Remarks by Vice President Mike Pence to the Federalist Society
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/196/
# Fetching document: Remarks by President Trump in Press Conference (Feb 16, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Press_Conference.txt (12266 words)
#
# Fetching document: Remarks by President Trump at Signing of H.J. Resolution 38 (Feb 16, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Signing_of_H_J__Resolution_38.txt (982 words)
#
# Fetching document: Remarks by President Trump in Listening Session with Members of Congress (Feb 16, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Listening_Session_with_Members_of_Congress.txt (961 words)
#
# Fetching document: Remarks by President Trump in Listening Session with the Retail Industry Leaders Association and Member Company CEOs (Feb 15, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Listening_Session_with_the_Retail_Industry_Leaders_Association_and_Member_Company_CEOs.txt (812 words)
#
# Fetching document: Remarks by President Trump and Prime Minister Netanyahu of Israel in Joint Press Conference (Feb 15, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Prime_Minister_Netanyahu_of_Israel_in_Joint_Press_Conference.txt (1723 words)
#
# Fetching document: Remarks by President Trump at Parent-Teacher Conference Listening Session (Feb 14, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Parent-Teacher_Conference_Listening_Session.txt (856 words)
#
# Fetching document: Remarks by President Trump at Swearing-In Ceremony for Treasury Secretary Mnuchin (Feb 13, 2017)
# Skipping Remarks by President Trump at Swearing-In Ceremony for Treasury Secretary Mnuchin (Feb 13, 2017) - Only 247 words.
# Fetching document: Remarks by President Trump and Prime Minister Trudeau of Canada in Roundtable with Women Entrepreneurs (Feb 13, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Prime_Minister_Trudeau_of_Canada_in_Roundtable_with_Women_Entrepreneurs.txt (566 words)
#
# Fetching document: Remarks by President Trump and Prime Minister Trudeau of Canada in Joint Press Conference (Feb 13, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Prime_Minister_Trudeau_of_Canada_in_Joint_Press_Conference.txt (1623 words)
#
# Fetching document: Remarks by the Vice President at a Swearing-in Ceremony for Secretary Price (Feb 10, 2017)
# Title does not contain 'trump': Remarks by the Vice President at a Swearing-in Ceremony for Secretary Price
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/195/
# Fetching document: Remarks by President Trump in Meeting with Manufacturing CEOs (Feb 23, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Meeting_with_Manufacturing_CEOs.txt (1739 words)
#
# Fetching document: Remarks by President Trump at Listening Session on Domestic and International Human Trafficking (Feb 23, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Listening_Session_on_Domestic_and_International_Human_Trafficking.txt (484 words)
#
# Fetching document: Remarks by the Vice President to Fabick Cat Employees (Feb 22, 2017)
# Title does not contain 'trump': Remarks by the Vice President to Fabick Cat Employees
# Fetching document: Remarks by President Trump in Budget Meeting (Feb 22, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Budget_Meeting.txt (647 words)
#
# Fetching document: Remarks by President Trump at the National Museum of African American History and Culture (Feb 21, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_the_National_Museum_of_African_American_History_and_Culture.txt (1211 words)
#
# Fetching document: Remarks by the Vice President and NATO Secretary General Stoltenberg at a JPA (Feb 20, 2017)
# Title does not contain 'trump': Remarks by the Vice President and NATO Secretary General Stoltenberg at a JPA
# Fetching document: Remarks by the Vice President and European Council President Tusk (Feb 20, 2017)
# Title does not contain 'trump': Remarks by the Vice President and European Council President Tusk
# Fetching document: Remarks by President Trump Announcing the Designation of Lieutenant General H.R. McMaster to National Security Advisor (Feb 20, 2017)
# Skipping Remarks by President Trump Announcing the Designation of Lieutenant General H.R. McMaster to National Security Advisor (Feb 20, 2017) - Only 349 words.
# Fetching document: Remarks by the Vice President at the Munich Security Conference (Feb 18, 2017)
# Title does not contain 'trump': Remarks by the Vice President at the Munich Security Conference
# Fetching document: Remarks by President Trump at Unveiling of Boeing 787 Dreamliner Aircraft (Feb 17, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Unveiling_of_Boeing_787_Dreamliner_Aircraft.txt (1939 words)
#
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/194/
# Fetching document: Excerpts from President Donald J. Trump’s Address to a Joint Session of Congress (Feb 28, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Excerpts_from_President_Donald_J__Trump_s_Address_to_a_Joint_Session_of_Congress.txt (898 words)
#
# Fetching document: Remarks by the Vice President at the Swearing-in Ceremony of Commerce Secretary Ross (Feb 28, 2017)
# Title does not contain 'trump': Remarks by the Vice President at the Swearing-in Ceremony of Commerce Secretary Ross
# Fetching document: Remarks by President Trump at Signing of H.R. 321 and H.R. 255 (Feb 28, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Signing_of_H_R__321_and_H_R__255.txt (736 words)
#
# Fetching document: Remarks by the Vice President at a Listening Session with Historically Black Colleges and Universities (Feb 27, 2017)
# Title does not contain 'trump': Remarks by the Vice President at a Listening Session with Historically Black Colleges and Universities
# Fetching document: Remarks by President Trump in Meeting with the National Governors Association (Feb 27, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Meeting_with_the_National_Governors_Association.txt (3656 words)
#
# Fetching document: Remarks by President Trump in Listening Session with Health Insurance Company CEOs (Feb 27, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Listening_Session_with_Health_Insurance_Company_CEOs.txt (1094 words)
#
# Fetching document: Remarks by President Trump at the 2017 Governors Ball (Feb 26, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_the_2017_Governors_Ball.txt (609 words)
#
# Fetching document: Remarks by President Trump at the Conservative Political Action Conference (Feb 24, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_the_Conservative_Political_Action_Conference.txt (5326 words)
#
# Fetching document: Remarks by President Trump and President Pedro Pablo Kuczynski of Peru Before Bilateral Meeting (Feb 24, 2017)
# Skipping Remarks by President Trump and President Pedro Pablo Kuczynski of Peru Before Bilateral Meeting (Feb 24, 2017) - Only 225 words.
# Fetching document: Remarks by President Trump at Signing of Executive Order on Regulatory Reform (Feb 24, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Signing_of_Executive_Order_on_Regulatory_Reform.txt (511 words)
#
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/193/
# Fetching document: Remarks by the Vice President and CMS Administrator Verma at a Swearing-in Ceremony (Mar 14, 2017)
# Title does not contain 'trump': Remarks by the Vice President and CMS Administrator Verma at a Swearing-in Ceremony
# Fetching document: Remarks by the Vice President in Louisville, KY on Obamacare (Mar 12, 2017)
# Title does not contain 'trump': Remarks by the Vice President in Louisville, KY on Obamacare
# Fetching document: Remarks by the Vice President to the Latino Coalition Policy Summit (Mar 10, 2017)
# Title does not contain 'trump': Remarks by the Vice President to the Latino Coalition Policy Summit
# Fetching document: Remarks by President Trump in a Healthcare Discussion with Key House Committee Chairmen (Mar 10, 2017)
# Skipping Remarks by President Trump in a Healthcare Discussion with Key House Committee Chairmen (Mar 10, 2017) - Only 423 words.
# Fetching document: Remarks by President Trump in National Economic Council Listening Session with CEOs of Small and Community Banks (Mar 9, 2017)
# Skipping Remarks by President Trump in National Economic Council Listening Session with CEOs of Small and Community Banks (Mar 9, 2017) - Only 244 words.
# Fetching document: Remarks by President Trump and Representative Steve Scalise in Meeting with the U.S. House Deputy Whip Team (Mar 7, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Representative_Steve_Scalise_in_Meeting_with_the_U_S__House_Deputy_Whip_Team.txt (821 words)
#
# Fetching document: Remarks by the Vice President on President Trump’s Vision for the Future (Mar 3, 2017)
# Skipping Remarks by the Vice President on President Trump’s Vision for the Future (Mar 3, 2017) - Only 10 words.
# Fetching document: Remarks by President Trump in Parent-Teacher Conference Listening Session (Mar 3, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Parent-Teacher_Conference_Listening_Session.txt (844 words)
#
# Fetching document: Remarks by President Trump Aboard the USS Gerald R. Ford (Mar 2, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_Aboard_the_USS_Gerald_R__Ford.txt (1024 words)
#
# Fetching document: Remarks by President Trump in Joint Address to Congress (Feb 28, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Joint_Address_to_Congress.txt (2846 words)
#
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/192/
# Fetching document: Remarks by President Trump in Roundtable Discussion on Vocational Training with U.S. and German Business Leaders (Mar 17, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Roundtable_Discussion_on_Vocational_Training_with_U_S__and_German_Business_Leaders.txt (1070 words)
#
# Fetching document: Remarks by President Trump, Congressman Steve Scalise, and Congressman Mark Walker at Republican Study Committee Meeting (Mar 17, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump__Congressman_Steve_Scalise__and_Congressman_Mark_Walker_at_Republican_Study_Committee_Meeting.txt (787 words)
#
# Fetching document: Remarks by President Trump and Veterans Affairs Secretary Shulkin at Veterans Affairs Listening Session (Mar 17, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Veterans_Affairs_Secretary_Shulkin_at_Veterans_Affairs_Listening_Session.txt (909 words)
#
# Fetching document: Joint Press Conference with President Trump and German Chancellor Merkel (Mar 17, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Joint_Press_Conference_with_President_Trump_and_German_Chancellor_Merkel.txt (1712 words)
#
# Fetching document: Remarks by President Trump and Vice President Pence at St. Patrick’s Day Reception East Room (Mar 16, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Vice_President_Pence_at_St__Patrick_s_Day_Reception_East_Room.txt (686 words)
#
# Fetching document: Remarks by the Vice President and Director of National Intelligence Dan Coats at a Swearing-in Ceremony (Mar 16, 2017)
# Title does not contain 'trump': Remarks by the Vice President and Director of National Intelligence Dan Coats at a Swearing-in Ceremony
# Fetching document: Remarks by President Trump and Taoiseach Enda Kenny of Ireland at Friends of Ireland Luncheon (Mar 16, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Taoiseach_Enda_Kenny_of_Ireland_at_Friends_of_Ireland_Luncheon.txt (563 words)
#
# Fetching document: Remarks by the Vice President to the American Ireland Fund National Gala (Mar 15, 2017)
# Title does not contain 'trump': Remarks by the Vice President to the American Ireland Fund National Gala
# Fetching document: Remarks by President Trump at American Center for Mobility | Detroit, MI (Mar 15, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_American_Center_for_Mobility___Detroit__MI.txt (2128 words)
#
# Fetching document: Remarks by the President on 250th Anniversary of the Birth of President Andrew Jackson (Mar 15, 2017)
# Title does not contain 'trump': Remarks by the President on 250th Anniversary of the Birth of President Andrew Jackson
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/191/
# Fetching document: Remarks by the Vice President in West Virginia (Mar 25, 2017)
# Title does not contain 'trump': Remarks by the Vice President in West Virginia
# Fetching document: Remarks by the President in TransCanada Keystone XL Pipeline Announcement (Mar 24, 2017)
# Title does not contain 'trump': Remarks by the President in TransCanada Keystone XL Pipeline Announcement
# Fetching document: Remarks by President Trump at Jobs Announcement with Charter Communications (Mar 24, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Jobs_Announcement_with_Charter_Communications.txt (683 words)
#
# Fetching document: Remarks by President Trump at Greek Independence Day Celebration (Mar 24, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Greek_Independence_Day_Celebration.txt (661 words)
#
# Fetching document: Remarks by the President in Meeting with Truckers and CEOS on Healthcare (Mar 23, 2017)
# Title does not contain 'trump': Remarks by the President in Meeting with Truckers and CEOS on Healthcare
# Fetching document: Remarks by President Trump Before Meeting with Members of the Congressional Black Caucus (Mar 22, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_Before_Meeting_with_Members_of_the_Congressional_Black_Caucus.txt (534 words)
#
# Fetching document: Remarks by President Trump and Administrator Seema Verma in Women in Healthcare Panel Meeting (Mar 22, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Administrator_Seema_Verma_in_Women_in_Healthcare_Panel_Meeting.txt (496 words)
#
# Fetching document: Remarks by the President at Signing of S.442, National Aeronautics and Space Administration Transition Authorization Act of 2017 (Mar 21, 2017)
# Title does not contain 'trump': Remarks by the President at Signing of S.442, National Aeronautics and Space Administration Transition Authorization Act of 2017
# Fetching document: Remarks by Vice President Mike Pence on Obamacare (Mar 20, 2017)
# Title does not contain 'trump': Remarks by Vice President Mike Pence on Obamacare
# Fetching document: President Donald J. Trump’s Weekly Address (Mar 18, 2017)
# Skipping President Donald J. Trump’s Weekly Address (Mar 18, 2017) - Only 10 words.
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/190/
# Fetching document: Remarks by President Trump and Vice President Pence at CEO Town Hall on Unleashing American Business (Apr 4, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Vice_President_Pence_at_CEO_Town_Hall_on_Unleashing_American_Business.txt (2403 words)
#
# Fetching document: Remarks by the Vice President to Dynalab Inc. (Apr 1, 2017)
# Title does not contain 'trump': Remarks by the Vice President to Dynalab Inc.
# Fetching document: Remarks by President Trump et al. at Signing of Trade Executive Orders (Mar 31, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_et_al__at_Signing_of_Trade_Executive_Orders.txt (905 words)
#
# Fetching document: Remarks by President Trump at Women’s Empowerment Panel (Mar 29, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Women_s_Empowerment_Panel.txt (1276 words)
#
# Fetching document: Remarks by President Trump in Listening Session on Opioids and Drug Abuse (Mar 29, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Listening_Session_on_Opioids_and_Drug_Abuse.txt (1367 words)
#
# Fetching document: Remarks by Vice President and Ambassador Friedman at a Swearing-in Ceremony (Mar 29, 2017)
# Title does not contain 'trump': Remarks by Vice President and Ambassador Friedman at a Swearing-in Ceremony
# Fetching document: Remarks by President Trump in Listening Session with the Fraternal Order of Police (Mar 28, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Listening_Session_with_the_Fraternal_Order_of_Police.txt (873 words)
#
# Fetching document: Remarks by President Trump at Signing of Executive Order to Create Energy Independence (Mar 28, 2017)
# Skipping Remarks by President Trump at Signing of Executive Order to Create Energy Independence (Mar 28, 2017) - Only 427 words.
# Fetching document: Remarks by President Trump and Vice President Pence in Roundtable with Women Small Business Owners (Mar 27, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Vice_President_Pence_in_Roundtable_with_Women_Small_Business_Owners.txt (1154 words)
#
# Fetching document: Remarks by the President on Signing House Joint Resolutions 37, 44, 57, and 58 under the Congressional Review Act (Mar 27, 2017)
# Title does not contain 'trump': Remarks by the President on Signing House Joint Resolutions 37, 44, 57, and 58 under the Congressional Review Act
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/189/
# Fetching document: Remarks by the Vice President to the US/ROK Business Community (Apr 16, 2017)
# Title does not contain 'trump': Remarks by the Vice President to the US/ROK Business Community
# Fetching document: Remarks by the Vice President and South Korean Acting President Hwang at a Joint Press Statement (Apr 14, 2017)
# Title does not contain 'trump': Remarks by the Vice President and South Korean Acting President Hwang at a Joint Press Statement
# Fetching document: Remarks by President Trump in Meeting with I-85 Bridge First Responders (Apr 13, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Meeting_with_I-85_Bridge_First_Responders.txt (1122 words)
#
# Fetching document: Joint Press Conference of President Trump and NATO Secretary General Stoltenberg (Apr 12, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Joint_Press_Conference_of_President_Trump_and_NATO_Secretary_General_Stoltenberg.txt (1821 words)
#
# Fetching document: Remarks by President Trump in Strategic and Policy CEO Discussion (Apr 11, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Strategic_and_Policy_CEO_Discussion.txt (1065 words)
#
# Fetching document: Remarks by President Trump and Justice Gorsuch at Swearing-in of Justice Gorsuch to the Supreme Court (Apr 10, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Justice_Gorsuch_at_Swearing-in_of_Justice_Gorsuch_to_the_Supreme_Court.txt (1071 words)
#
# Fetching document: Remarks by President Trump After Meeting with President Xi of China (Apr 7, 2017)
# Skipping Remarks by President Trump After Meeting with President Xi of China (Apr 7, 2017) - Only 186 words.
# Fetching document: Remarks by President Trump and Vice President Pence at the Wounded Warrior Project Soldier Ride Event (Apr 6, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Vice_President_Pence_at_the_Wounded_Warrior_Project_Soldier_Ride_Event.txt (851 words)
#
# Fetching document: Remarks by President Trump and His Majesty King Abdullah II of Jordan in Joint Press Conference (Apr 5, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_His_Majesty_King_Abdullah_II_of_Jordan_in_Joint_Press_Conference.txt (1827 words)
#
# Fetching document: Remarks by President Trump at 2017 North America’s Building Trades Unions National Legislative Conference (Apr 4, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_2017_North_America_s_Building_Trades_Unions_National_Legislative_Conference.txt (1651 words)
#
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/188/
# Fetching document: Remarks by the Vice President and Australian Prime Minister Turnbull at a Press Conference (Apr 22, 2017)
# Title does not contain 'trump': Remarks by the Vice President and Australian Prime Minister Turnbull at a Press Conference
# Fetching document: Remarks by President Trump at Signing of Financial Services Executive Orders (Apr 21, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Signing_of_Financial_Services_Executive_Orders.txt (989 words)
#
# Fetching document: Remarks by the Vice President and Indonesian President Widodo to the Press (Apr 20, 2017)
# Title does not contain 'trump': Remarks by the Vice President and Indonesian President Widodo to the Press
# Fetching document: Remarks by the Vice President to US-Japanese Business Community (Apr 19, 2017)
# Title does not contain 'trump': Remarks by the Vice President to US-Japanese Business Community
# Fetching document: Remarks by the Vice President Aboard USS Ronald Reagan (Apr 19, 2017)
# Title does not contain 'trump': Remarks by the Vice President Aboard USS Ronald Reagan
# Fetching document: Remarks by President Trump Welcoming the Super Bowl LI Champions, New England Patriots (Apr 19, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_Welcoming_the_Super_Bowl_LI_Champions__New_England_Patriots.txt (1282 words)
#
# Fetching document: Remarks by President Trump on Buy American, Hire American Executive Order (Apr 18, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_on_Buy_American__Hire_American_Executive_Order.txt (2861 words)
#
# Fetching document: Remarks to the Troops by the Vice President with Q&A, Demilitarized Zone, South Korea (Apr 17, 2017)
# Title does not contain 'trump': Remarks to the Troops by the Vice President with Q&A, Demilitarized Zone, South Korea
# Fetching document: Remarks by President Trump and First Lady Melania Trump at the 2017 White House Easter Egg Roll (Apr 17, 2017)
# Skipping Remarks by President Trump and First Lady Melania Trump at the 2017 White House Easter Egg Roll (Apr 17, 2017) - Only 331 words.
# Fetching document: Remarks by the Vice President and Mrs. Pence to the Troops, Seoul, South Korea (Apr 16, 2017)
# Title does not contain 'trump': Remarks by the Vice President and Mrs. Pence to the Troops, Seoul, South Korea
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/187/
# Fetching document: Remarks by President Trump at Signing of Executive Order on the Antiquities Act (Apr 26, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Signing_of_Executive_Order_on_the_Antiquities_Act.txt (1047 words)
#
# Fetching document: Remarks by President Trump at National Teacher of the Year Event (Apr 26, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_National_Teacher_of_the_Year_Event.txt (479 words)
#
# Fetching document: Remarks by the Vice President at a Meeting with US and Indonesian Business Leaders (Apr 25, 2017)
# Title does not contain 'trump': Remarks by the Vice President at a Meeting with US and Indonesian Business Leaders
# Fetching document: Remarks by President Trump at United States Holocaust Memorial Museum National Days of Remembrance (Apr 25, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_United_States_Holocaust_Memorial_Museum_National_Days_of_Remembrance.txt (676 words)
#
# Fetching document: Remarks by President Trump in Farmers Roundtable and Executive Order Signing Promoting Agriculture and Rural Prosperity in America (Apr 25, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Farmers_Roundtable_and_Executive_Order_Signing_Promoting_Agriculture_and_Rural_Prosperity_in_America.txt (1066 words)
#
# Fetching document: Remarks to the Troops by the Vice President, Honolulu, HI (Apr 24, 2017)
# Title does not contain 'trump': Remarks to the Troops by the Vice President, Honolulu, HI
# Fetching document: Remarks by President Trump at a Working Lunch with U.N. Security Council Ambassadors (Apr 24, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_a_Working_Lunch_with_U_N__Security_Council_Ambassadors.txt (1115 words)
#
# Fetching document: Remarks by President Trump in Video Call with NASA Astronauts Aboard the International Space Station (Apr 24, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Video_Call_with_NASA_Astronauts_Aboard_the_International_Space_Station.txt (1202 words)
#
# Fetching document: Remarks by the Vice President to the US/ROK Business Community (Apr 24, 2017)
# Title does not contain 'trump': Remarks by the Vice President to the US/ROK Business Community
# Fetching document: Remarks by the Vice President to the US-Australian Business Community (Apr 22, 2017)
# Title does not contain 'trump': Remarks by the Vice President to the US-Australian Business Community
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/186/
# Fetching document: Remarks by President Trump at Presentation of the Commander-in-Chief Trophy to the United States Air Force Academy (May 2, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Presentation_of_the_Commander-in-Chief_Trophy_to_the_United_States_Air_Force_Academy.txt (2479 words)
#
# Fetching document: Remarks by the Vice President to Small Business Week Awards Program (May 1, 2017)
# Title does not contain 'trump': Remarks by the Vice President to Small Business Week Awards Program
# Fetching document: Remarks by the Vice President to Independent Community Bankers of America (May 1, 2017)
# Title does not contain 'trump': Remarks by the Vice President to Independent Community Bankers of America
# Fetching document: Remarks by the Vice President at the Christening of the USS Indiana (Apr 29, 2017)
# Title does not contain 'trump': Remarks by the Vice President at the Christening of the USS Indiana
# Fetching document: Remarks by President Trump at Signing of Executive Orders on Trade (Apr 29, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Signing_of_Executive_Orders_on_Trade.txt (597 words)
#
# Fetching document: Remarks by Vice President Pence at Swearing-In Ceremony for Secretary of Labor Alexander Acosta (Apr 28, 2017)
# Title does not contain 'trump': Remarks by Vice President Pence at Swearing-In Ceremony for Secretary of Labor Alexander Acosta
# Fetching document: Remarks by President Trump at Signing of Executive Order on an America-First Offshore Energy Strategy (Apr 28, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Signing_of_Executive_Order_on_an_America-First_Offshore_Energy_Strategy.txt (533 words)
#
# Fetching document: Remarks by President Trump at the National Rifle Association Leadership Forum (Apr 28, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_the_National_Rifle_Association_Leadership_Forum.txt (3147 words)
#
# Fetching document: Remarks by President Trump in Meeting with President Macri of Argentina (Apr 27, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Meeting_with_President_Macri_of_Argentina.txt (545 words)
#
# Fetching document: Remarks by President Trump at Signing of Executive Order on Federalism Education (Apr 26, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Signing_of_Executive_Order_on_Federalism_Education.txt (769 words)
#
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/185/
# Fetching document: Remarks by Vice President Pence at the World Summit in Defense of Persecuted Christians (May 11, 2017)
# Title does not contain 'trump': Remarks by Vice President Pence at the World Summit in Defense of Persecuted Christians
# Fetching document: Remarks by the Vice President and Mrs. Pence to Military Families (May 9, 2017)
# Title does not contain 'trump': Remarks by the Vice President and Mrs. Pence to Military Families
# Fetching document: Remarks by the Vice President Honoring Public Service Recognition Week and National Military Appreciation Month (May 8, 2017)
# Title does not contain 'trump': Remarks by the Vice President Honoring Public Service Recognition Week and National Military Appreciation Month
# Fetching document: Remarks by Vice President Pence at Cinco de Mayo Reception (May 4, 2017)
# Title does not contain 'trump': Remarks by Vice President Pence at Cinco de Mayo Reception
# Fetching document: Remarks by President Trump at the National Day of Prayer Event and Signing of the Executive Order on Promoting Free Speech and Religious Liberty (May 4, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_the_National_Day_of_Prayer_Event_and_Signing_of_the_Executive_Order_on_Promoting_Free_Speech_and_Religious_Liberty.txt (1150 words)
#
# Fetching document: Remarks by Vice President Pence at Susan B. Anthony List Campaign for Life Gala (May 4, 2017)
# Title does not contain 'trump': Remarks by Vice President Pence at Susan B. Anthony List Campaign for Life Gala
# Fetching document: Remarks by President Trump on Healthcare Vote in the House of Representatives (May 4, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_on_Healthcare_Vote_in_the_House_of_Representatives.txt (984 words)
#
# Fetching document: Remarks by Vice President Pence at a School Choice Event (May 3, 2017)
# Title does not contain 'trump': Remarks by Vice President Pence at a School Choice Event
# Fetching document: Remarks by President Trump and President Abbas of the Palestinian Authority in Joint Statement (May 3, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_President_Abbas_of_the_Palestinian_Authority_in_Joint_Statement.txt (665 words)
#
# Fetching document: Remarks by Vice President Pence at an Israel Independence Day Commemoration Event (May 2, 2017)
# Title does not contain 'trump': Remarks by Vice President Pence at an Israel Independence Day Commemoration Event
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/184/
# Fetching document: Remarks by President Trump at the Israel Museum (May 23, 2017)
# Skipping Remarks by President Trump at the Israel Museum (May 23, 2017) - Only 204 words.
# Fetching document: Remarks by President Trump and President Abbas of the Palestinian Authority in Joint Statements (May 23, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_President_Abbas_of_the_Palestinian_Authority_in_Joint_Statements.txt (777 words)
#
# Fetching document: Remarks by President Trump and President Abbas of the Palestinian Authority in Joint Statements (May 23, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_President_Abbas_of_the_Palestinian_Authority_in_Joint_Statements.txt (777 words)
#
# Fetching document: Remarks by the Vice President at Grove City College Commencement (May 20, 2017)
# Title does not contain 'trump': Remarks by the Vice President at Grove City College Commencement
# Fetching document: Remarks by President Trump and President Santos of Colombia in Joint Press Conference (May 18, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_President_Santos_of_Colombia_in_Joint_Press_Conference.txt (2085 words)
#
# Fetching document: Remarks by the Vice President at the US Chamber of Commerce’s Invest in America Summit (May 18, 2017)
# Title does not contain 'trump': Remarks by the Vice President at the US Chamber of Commerce’s Invest in America Summit
# Fetching document: Remarks by Vice President Pence at a Reception for Asian American and Pacific Islander Heritage Month (May 17, 2017)
# Title does not contain 'trump': Remarks by Vice President Pence at a Reception for Asian American and Pacific Islander Heritage Month
# Fetching document: Remarks by President Trump at United States Coast Guard Academy Commencement Ceremony (May 17, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_United_States_Coast_Guard_Academy_Commencement_Ceremony.txt (3522 words)
#
# Fetching document: Remarks by President Trump and President Erdogan of Turkey in Joint Statement (May 16, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_President_Erdogan_of_Turkey_in_Joint_Statement.txt (634 words)
#
# Fetching document: Remarks by the Vice President at the National Peace Officers” Memorial Service (May 15, 2017)
# Title does not contain 'trump': Remarks by the Vice President at the National Peace Officers” Memorial Service
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/183/
# Fetching document: Remarks by the Vice President at a Listening Session on Healthcare with Women Entrepreneurs (Jun 5, 2017)
# Title does not contain 'trump': Remarks by the Vice President at a Listening Session on Healthcare with Women Entrepreneurs
# Fetching document: Remarks by President Trump at Announcement of Air Traffic Control Initiative (Jun 5, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Announcement_of_Air_Traffic_Control_Initiative.txt (1543 words)
#
# Fetching document: Remarks by the Vice President Introducing President Trump’s Statement on the Paris Accord (Jun 1, 2017)
# Skipping Remarks by the Vice President Introducing President Trump’s Statement on the Paris Accord (Jun 1, 2017) - Only 6 words.
# Fetching document: Statement by President Trump on the Paris Climate Accord (Jun 1, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Statement_by_President_Trump_on_the_Paris_Climate_Accord.txt (1503 words)
#
# Fetching document: Remarks by President Trump at Arlington National Cemetery (May 29, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Arlington_National_Cemetery.txt (516 words)
#
# Fetching document: Remarks by the Vice President at the Project Hero Bike Ride (May 29, 2017)
# Title does not contain 'trump': Remarks by the Vice President at the Project Hero Bike Ride
# Fetching document: Remarks by the Vice President at the US Naval Academy Commencement Ceremony (May 26, 2017)
# Title does not contain 'trump': Remarks by the Vice President at the US Naval Academy Commencement Ceremony
# Fetching document: Remarks by President Trump at NATO Unveiling of the Article 5 and Berlin Wall Memorials – Brussels, Belgium (May 25, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_NATO_Unveiling_of_the_Article_5_and_Berlin_Wall_Memorials___Brussels__Belgium.txt (921 words)
#
# Fetching document: Remarks by the Vice President at Cajun Industries, Baton Rouge, LA (May 24, 2017)
# Title does not contain 'trump': Remarks by the Vice President at Cajun Industries, Baton Rouge, LA
# Fetching document: Remarks by President Trump at Yad Vashem (May 23, 2017)
# Skipping Remarks by President Trump at Yad Vashem (May 23, 2017) - Only 140 words.
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/182/
# Fetching document: Remarks by the Vice President to the Faith and Freedom Coalition (Jun 10, 2017)
# Title does not contain 'trump': Remarks by the Vice President to the Faith and Freedom Coalition
# Fetching document: Remarks to Troops and Family Members by the Vice President, Dobbins Air Reserve Base, GA (Jun 9, 2017)
# Title does not contain 'trump': Remarks to Troops and Family Members by the Vice President, Dobbins Air Reserve Base, GA
# Fetching document: Remarks by President Trump on Regulatory Relief (Jun 9, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_on_Regulatory_Relief.txt (2256 words)
#
# Fetching document: Remarks by President Trump and President Iohannis of Romania in a Joint Press Conference (Jun 9, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_President_Iohannis_of_Romania_in_a_Joint_Press_Conference.txt (1838 words)
#
# Fetching document: Remarks by Vice President Pence at Infrastructure Summit Working Luncheon (Jun 8, 2017)
# Title does not contain 'trump': Remarks by Vice President Pence at Infrastructure Summit Working Luncheon
# Fetching document: Remarks by President Trump at the Top of the Infrastructure Summit with Governors and Mayors (Jun 8, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_the_Top_of_the_Infrastructure_Summit_with_Governors_and_Mayors.txt (816 words)
#
# Fetching document: Remarks by President Trump at the Faith and Freedom Coalition’s Road to Majority Conference (Jun 8, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_the_Faith_and_Freedom_Coalition_s_Road_to_Majority_Conference.txt (2678 words)
#
# Fetching document: Remarks by the Vice President at the 2017 Astronaut Selection Announcement (Jun 7, 2017)
# Title does not contain 'trump': Remarks by the Vice President at the 2017 Astronaut Selection Announcement
# Fetching document: Remarks by the Vice President at the National Catholic Prayer Breakfast (Jun 6, 2017)
# Title does not contain 'trump': Remarks by the Vice President at the National Catholic Prayer Breakfast
# Fetching document: Remarks by Vice President Pence in Introducing President Trump at Announcement of Air Traffic Control Initiative (Jun 5, 2017)
# Skipping Remarks by Vice President Pence in Introducing President Trump at Announcement of Air Traffic Control Initiative (Jun 5, 2017) - Only 5 words.
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/181/
# Fetching document: Remarks by President Trump During Roundtable with the American Technology Council (Jun 19, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_During_Roundtable_with_the_American_Technology_Council.txt (852 words)
#
# Fetching document: Remarks by the Vice President on the Policy of the United States Towards Cuba (Jun 16, 2017)
# Title does not contain 'trump': Remarks by the Vice President on the Policy of the United States Towards Cuba
# Fetching document: Remarks by President Trump on the Policy of the United States Towards Cuba (Jun 16, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_on_the_Policy_of_the_United_States_Towards_Cuba.txt (3160 words)
#
# Fetching document: Remarks by President Trump at Signing of an Executive Order on Apprenticeship and Workforce of Tomorrow Initiatives (Jun 15, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Signing_of_an_Executive_Order_on_Apprenticeship_and_Workforce_of_Tomorrow_Initiatives.txt (1763 words)
#
# Fetching document: Message from President Donald J. Trump on the Congressional Baseball Game (Jun 15, 2017)
# Skipping Message from President Donald J. Trump on the Congressional Baseball Game (Jun 15, 2017) - Only 290 words.
# Fetching document: Statement by President Trump on the Shooting in Virginia (Jun 14, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Statement_by_President_Trump_on_the_Shooting_in_Virginia.txt (473 words)
#
# Fetching document: Remarks by the Vice President on Healthcare (Jun 13, 2017)
# Title does not contain 'trump': Remarks by the Vice President on Healthcare
# Fetching document: Remarks by President Trump, Ivanka Trump and Wisconsin Governor Walker at Workforce Development Roundtable Discussion (Jun 13, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump__Ivanka_Trump_and_Wisconsin_Governor_Walker_at_Workforce_Development_Roundtable_Discussion.txt (841 words)
#
# Fetching document: Remarks by President Trump on Healthcare (Jun 13, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_on_Healthcare.txt (597 words)
#
# Fetching document: Remarks by President Trump in Welcoming the 2016 NCAA National Football Champion Clemson Tigers (Jun 12, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Welcoming_the_2016_NCAA_National_Football_Champion_Clemson_Tigers.txt (1459 words)
#
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/180/
# Fetching document: Remarks by Vice President Pence to Troops (Jun 23, 2017)
# Title does not contain 'trump': Remarks by Vice President Pence to Troops
# ...
# Skipping Remarks by President Trump in a Meeting with Families of North Korean Abductees (Nov 6, 2017) - Only 140 words.
# Fetching document: Remarks by President Trump and Prime Minister Abe of Japan in Joint Press Conference | Tokyo, Japan (Nov 6, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Prime_Minister_Abe_of_Japan_in_Joint_Press_Conference___Tokyo__Japan.txt (2476 words)
#
# Fetching document: Remarks by President Trump to Servicemembers at Yokota Air Base (Nov 5, 2017)
# Skipping Remarks by President Trump to Servicemembers at Yokota Air Base (Nov 5, 2017) - Only 336 words.
# Fetching document: Remarks by the Vice President and Community Participants on Tax Reform (Nov 4, 2017)
# Title does not contain 'trump': Remarks by the Vice President and Community Participants on Tax Reform
# Fetching document: Remarks by President Trump at Meeting with House Republican Leaders and Republican Members of the House Ways and Means Committee (Nov 2, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Meeting_with_House_Republican_Leaders_and_Republican_Members_of_the_House_Ways_and_Means_Committee.txt (2070 words)
#
# Fetching document: Remarks by President Trump in Jobs Announcement (Nov 2, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Jobs_Announcement.txt (1276 words)
#
# Fetching document: Remarks by the Vice President on Tax Reform in Orlando, FL (Nov 2, 2017)
# Title does not contain 'trump': Remarks by the Vice President on Tax Reform in Orlando, FL
# Fetching document: Remarks by President Trump in Cabinet Meeting (Nov 1, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Cabinet_Meeting.txt (2577 words)
#
# Fetching document: Remarks by President Trump and Business Leaders Before Tax Reform Industry Meeting (Oct 31, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Business_Leaders_Before_Tax_Reform_Industry_Meeting.txt (1710 words)
#
# Fetching document: Remarks to Airmen at Minot Air Force Base by Vice President Pence (Oct 27, 2017)
# Title does not contain 'trump': Remarks to Airmen at Minot Air Force Base by Vice President Pence
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/161/
# Fetching document: Remarks by President Trump to the National Assembly of the Republic of Korea | Seoul, Republic of Korea (Nov 7, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_to_the_National_Assembly_of_the_Republic_of_Korea___Seoul__Republic_of_Korea.txt (3008 words)
#
# Fetching document: Remarks by President Trump Before Operational Briefing at Camp Humphreys (Nov 7, 2017)
# Skipping Remarks by President Trump Before Operational Briefing at Camp Humphreys (Nov 7, 2017) - Only 363 words.
# Fetching document: Remarks by President Trump and President Moon of Korea Before Expanded Bilateral Meeting (Nov 7, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_President_Moon_of_Korea_Before_Expanded_Bilateral_Meeting.txt (694 words)
#
# Fetching document: Remarks by President Trump and President Moon of the Republic of Korea Before One-on-One Bilateral Meeting (Nov 7, 2017)
# Skipping Remarks by President Trump and President Moon of the Republic of Korea Before One-on-One Bilateral Meeting (Nov 7, 2017) - Only 194 words.
# Fetching document: Remarks by President Trump and President Moon of the Republic of Korea in Joint Press Conference | Seoul, Republic of Korea (Nov 7, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_President_Moon_of_the_Republic_of_Korea_in_Joint_Press_Conference___Seoul__Republic_of_Korea.txt (1838 words)
#
# Fetching document: Remarks by President Trump and President Moon of the Republic of Korea at State Dinner | Seoul, Republic of Korea (Nov 7, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_President_Moon_of_the_Republic_of_Korea_at_State_Dinner___Seoul__Republic_of_Korea.txt (486 words)
#
# Fetching document: Remarks by President Trump and Prime Minister Abe of Japan Before Working Lunch | Tokyo, Japan (Nov 6, 2017)
# Skipping Remarks by President Trump and Prime Minister Abe of Japan Before Working Lunch | Tokyo, Japan (Nov 6, 2017) - Only 192 words.
# Fetching document: Remarks by President Trump to U.S. and Japanese Business Leaders | Tokyo, Japan (Nov 6, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_to_U_S__and_Japanese_Business_Leaders___Tokyo__Japan.txt (2958 words)
#
# Fetching document: Remarks by President Trump and Prime Minister Abe of Japan Before Bilateral Meeting | Tokyo, Japan (Nov 6, 2017)
# Skipping Remarks by President Trump and Prime Minister Abe of Japan Before Bilateral Meeting | Tokyo, Japan (Nov 6, 2017) - Only 93 words.
# Fetching document: Remarks by President Trump and Prime Minister Abe of Japan at State Dinner | Tokyo, Japan (Nov 6, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_Prime_Minister_Abe_of_Japan_at_State_Dinner___Tokyo__Japan.txt (1276 words)
#
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/160/
# Fetching document: Remarks by President Trump in Press Gaggle Aboard Air Force One en route Hanoi, Vietnam (Nov 11, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Press_Gaggle_Aboard_Air_Force_One_en_route_Hanoi__Vietnam.txt (4004 words)
#
# Fetching document: Remarks by President Trump at APEC CEO Summit | Da Nang, Vietnam (Nov 10, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_APEC_CEO_Summit___Da_Nang__Vietnam.txt (3481 words)
#
# Fetching document: Remarks by President Trump in Meet-and-Greet with Vietnam War Veterans (Nov 10, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Meet-and-Greet_with_Vietnam_War_Veterans.txt (697 words)
#
# Fetching document: Remarks by President Trump at Business Event with President Xi of China | Beijing, China (Nov 9, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Business_Event_with_President_Xi_of_China___Beijing__China.txt (931 words)
#
# Fetching document: Remarks by President Trump and President Xi of China Before Expanded Bilateral Meeting | Beijing, China (Nov 9, 2017)
# Skipping Remarks by President Trump and President Xi of China Before Expanded Bilateral Meeting | Beijing, China (Nov 9, 2017) - Only 413 words.
# Fetching document: Remarks by President Trump and President Xi of China in Joint Press Statement | Beijing, China (Nov 9, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_President_Xi_of_China_in_Joint_Press_Statement___Beijing__China.txt (822 words)
#
# Fetching document: Remarks by the Vice President, Secretary Acosta, Senator Young and Community Participants in a Tax Reform Roundtable (Nov 9, 2017)
# Title does not contain 'trump': Remarks by the Vice President, Secretary Acosta, Senator Young and Community Participants in a Tax Reform Roundtable
# Fetching document: Remarks by President Trump and President Xi of China at State Dinner | Beijing, China (Nov 9, 2017)
# Skipping Remarks by President Trump and President Xi of China at State Dinner | Beijing, China (Nov 9, 2017) - Only 420 words.
# Fetching document: Remarks by the Vice President and Mrs. Pence at the First Baptist Church Prayer Vigil (Nov 8, 2017)
# Title does not contain 'trump': Remarks by the Vice President and Mrs. Pence at the First Baptist Church Prayer Vigil
# Fetching document: Remarks by the Vice President at a Law Enforcement Briefing on the Sutherland Springs Shooting (Nov 8, 2017)
# Title does not contain 'trump': Remarks by the Vice President at a Law Enforcement Briefing on the Sutherland Springs Shooting
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/159/
# Fetching document: Remarks by President Trump, Prime Minister Turnbull of Australia, and Prime Minister Abe of Japan Before Trilateral Meeting | Manila, Philippines (Nov 13, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump__Prime_Minister_Turnbull_of_Australia__and_Prime_Minister_Abe_of_Japan_Before_Trilateral_Meeting___Manila__Philippines.txt (481 words)
#
# Fetching document: Remarks by President Trump and President Duterte of the Philippines Before Bilateral Meeting | Manila, Philippines (Nov 13, 2017)
# Skipping Remarks by President Trump and President Duterte of the Philippines Before Bilateral Meeting | Manila, Philippines (Nov 13, 2017) - Only 187 words.
# Fetching document: Remarks by President Trump at 5th U.S.-ASEAN Summit (Nov 13, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_5th_U_S_-ASEAN_Summit.txt (590 words)
#
# Fetching document: Remarks by President Trump and Prime Minister Modi of India Before Bilateral Meeting | Manila, Philippines (Nov 13, 2017)
# Skipping Remarks by President Trump and Prime Minister Modi of India Before Bilateral Meeting | Manila, Philippines (Nov 13, 2017) - Only 214 words.
# Fetching document: Remarks by President Trump Before Expanded Bilateral Meeting with Secretary General Trong of the Communist Party of Vietnam | Hanoi, Vietnam (Nov 12, 2017)
# Skipping Remarks by President Trump Before Expanded Bilateral Meeting with Secretary General Trong of the Communist Party of Vietnam | Hanoi, Vietnam (Nov 12, 2017) - Only 175 words.
# Fetching document: Remarks by President Trump Before Bilateral Meeting with Prime Minister Phuc of Vietnam | Hanoi, Vietnam (Nov 12, 2017)
# Skipping Remarks by President Trump Before Bilateral Meeting with Prime Minister Phuc of Vietnam | Hanoi, Vietnam (Nov 12, 2017) - Only 419 words.
# Fetching document: Remarks by President Trump Before Bilateral Meeting with President Quang of Vietnam | Hanoi, Vietnam (Nov 12, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_Before_Bilateral_Meeting_with_President_Quang_of_Vietnam___Hanoi__Vietnam.txt (538 words)
#
# Fetching document: Remarks by President Trump and President Quang of Vietnam in Joint Press Conference | Hanoi, Vietnam (Nov 11, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_and_President_Quang_of_Vietnam_in_Joint_Press_Conference___Hanoi__Vietnam.txt (1458 words)
#
# Fetching document: Remarks by the Vice President at the National Veterans Day Observance (Nov 11, 2017)
# Title does not contain 'trump': Remarks by the Vice President at the National Veterans Day Observance
# Fetching document: Remarks by President Trump and President Quang of Vietnam at State Banquet (Nov 11, 2017)
# Skipping Remarks by President Trump and President Quang of Vietnam at State Banquet (Nov 11, 2017) - Only 318 words.
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/158/
# Fetching document: Remarks by President Trump Before Marine One Departure (Nov 21, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_Before_Marine_One_Departure.txt (519 words)
#
# Fetching document: Remarks by President Trump at the National Thanksgiving Turkey Pardoning Ceremony (Nov 21, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_the_National_Thanksgiving_Turkey_Pardoning_Ceremony.txt (759 words)
#
# Fetching document: Remarks by the Vice President at ASEAN (Nov 21, 2017)
# Title does not contain 'trump': Remarks by the Vice President at ASEAN
# Fetching document: Remarks by the Vice President and Japanese Deputy Prime Minister Aso at a Press Conference (Nov 20, 2017)
# Title does not contain 'trump': Remarks by the Vice President and Japanese Deputy Prime Minister Aso at a Press Conference
# Fetching document: Remarks by President Trump Before Cabinet Meeting (Nov 20, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_Before_Cabinet_Meeting.txt (1305 words)
#
# Fetching document: Remarks by the Vice President at the Tax Foundation Annual Dinner (Nov 16, 2017)
# Title does not contain 'trump': Remarks by the Vice President at the Tax Foundation Annual Dinner
# Fetching document: Remarks by President Trump on His Trip to Asia (Nov 15, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_on_His_Trip_to_Asia.txt (2134 words)
#
# Fetching document: Remarks Followed by Q&A by the Vice President at the Wall Street Journal’s CEO Council Meeting (Nov 14, 2017)
# Title does not contain 'trump': Remarks Followed by Q&A by the Vice President at the Wall Street Journal’s CEO Council Meeting
# Fetching document: Remarks by President Trump in Press Gaggle After 12th East Asia Summit | Manila, Philippines (Nov 14, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Press_Gaggle_After_12th_East_Asia_Summit___Manila__Philippines.txt (780 words)
#
# Fetching document: Remarks by President Trump in Press Gaggle Aboard Air Force One en route Honolulu, Hawaii (Nov 14, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Press_Gaggle_Aboard_Air_Force_One_en_route_Honolulu__Hawaii.txt (851 words)
#
# Fetching page: https://trumpwhitehouse.archives.gov/remarks/page/157/
# Fetching document: Remarks by LTG H.R. McMaster at the Reagan National Defense Forum: Reclaiming America’s Strategic Confidence (Dec 2, 2017)
# Title does not contain 'trump': Remarks by LTG H.R. McMaster at the Reagan National Defense Forum: Reclaiming America’s Strategic Confidence
# Fetching document: Remarks by President Trump and His Highness Prince Salman bin Hamad bin Isa al Khalifa, Crown Prince of Bahrain Before Bilateral Meeting (Nov 30, 2017)
# Skipping Remarks by President Trump and His Highness Prince Salman bin Hamad bin Isa al Khalifa, Crown Prince of Bahrain Before Bilateral Meeting (Nov 30, 2017) - Only 125 words.
# Fetching document: Remarks by President Trump on Tax Reform (Nov 29, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_on_Tax_Reform.txt (6768 words)
#
# Fetching document: Remarks by the Vice President to the Hudson Institute’s Herman Kahn Award Dinner (Nov 28, 2017)
# Title does not contain 'trump': Remarks by the Vice President to the Hudson Institute’s Herman Kahn Award Dinner
# Fetching document: Remarks by President Trump in Meeting with Congressional Leadership (Nov 28, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_in_Meeting_with_Congressional_Leadership.txt (599 words)
#
# Fetching document: Remarks by the Vice President Commemorating U.N. Vote Establishing Israel (Nov 28, 2017)
# Title does not contain 'trump': Remarks by the Vice President Commemorating U.N. Vote Establishing Israel
# Fetching document: Remarks by President Trump at an Event Honoring the Native American Code Talkers (Nov 27, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_an_Event_Honoring_the_Native_American_Code_Talkers.txt (964 words)
#
# Fetching document: Remarks by President Trump at Signing of Executive Order on Improving Accountability and Whistleblower Protection (Nov 27, 2017)
# Saved to Google Drive: /content/drive/MyDrive/TFG/POST_ELEC_SCRIPTS/Remarks_by_President_Trump_at_Signing_of_Executive_Order_on_Improving_Accountability_and_Whistleblower_Protection.txt (1316 words)
#
# Scraping stopped with 200 documents scraped until year 2017

# %% [markdown]
# ## EXTRAS

# %%
# BASE_URL = "https://trumpwhitehouse.archives.gov"
# start_url = "https://trumpwhitehouse.archives.gov/remarks/page/199/"

# response = requests.get(start_url)
# soup = BeautifulSoup(response.text, "html.parser")
# articles = soup.find_all("article")

# i = 0
# for article in articles:
#   # if i<1:
#     title_link = article.find("a")
#     title = title_link.text.strip()
#     link = title_link["href"]
#     date = article.find("time").text.strip()
#     # i += 1



# doc_response = requests.get(link)
# doc_soup = BeautifulSoup(doc_response.text, "html.parser")
# content_div = doc_soup.find("div", {"class": "page-content__content editor"})
# paragraphs = content_div.find_all("p")  # Get all <p> elements
# useful_text = "\n".join(p.get_text(strip=True) for p in paragraphs)  # Join text content
# ut =  extract_trump_statements(useful_text)
# print(ut)
# # print(text)

# %%
# lines = useful_text.split("\n")

# out_lines = []
# capturing = True

# for line in lines:
#     line = line.strip()

#     # Stop capturing if "END" is found
#     if re.match(r'^END\d', line):
#         capturing = False
#         break  # Stop processing further lines

#     # print(line)
#     if re.match(r'^(PRESIDENT TRUMP:|THE PRESIDENT:|Donald Trump:|TRUMP:|President Trump:|Mr. Trump:)', line, re.IGNORECASE):
#         print(2)
#         capturing = True  # Start capturing Trump's speech
#         line = re.sub(r'^(PRESIDENT TRUMP:|THE PRESIDENT:|Donald Trump:|TRUMP:|President Trump:|Mr. Trump:)', "", line, flags=re.IGNORECASE).strip()
#         out_lines.append(line)

#     # Stop capturing if another speaker is detected
#     elif re.match(r'^[A-Z\s.]+[:]', line):
#         print(line)
#         print(0)
#         capturing = False

#     elif capturing:
#         # print(1)
#         out_lines.append(line)

# uts = "\n".join(out_lines).strip()
# print(uts)
